# %%
import matplotlib.pyplot as plt


x=[2,3]
y=[4,5]
x1=[5,6]
y1=[1,2]
plt.title("Graph")
plt.xlabel("Distance")
plt.ylabel("Time")
plt.plot(x,y,color='y',label="money",linewidth=2)
plt.plot(x1,y1,color='r',label="time")
plt.grid(True,color='b')

plt.legend()
plt.show()
